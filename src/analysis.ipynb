# %%
import geopandas as gpd

# %%
bonn = gpd.read_file("/home/emily/thesis_BA/Bonn_temp.json")
bonn
# Out:
#                    id  index  pop_density  population  mean_self00:00:00  \
# 0     891fa1106d3ffff     10     0.057332    0.005345          84.534768
# 1     891fa11339bffff     31     0.020500    0.001911          84.176972
# 2     891fa1133a7ffff     37     0.442179    0.041223          84.653782
# 3     891fa113297ffff     46     9.141619    0.851893          89.567568
# 4     891fa11306bffff     54     1.578522    0.147124          84.292683
# ...               ...    ...          ...         ...                ...
# 2252  891fa11a36bffff  21348     0.000000    0.000000          75.891892
# 2253  891fa118c83ffff  21348     0.000000    0.000000          78.719731
# 2254  891fa11aa6bffff  21348     0.000000    0.000000          76.564036
# 2255  891fa11b1bbffff  21348     0.000000    0.000000          85.285930
# 2256  891fa118503ffff  21348     0.000000    0.000000          77.977683
#
#       reach_self00:00:00  mean_self01:00:00  reach_self01:00:00  \
# ...

# %%
pivot = bonn.loc[:, bonn.columns.str.startswith("mean")]
pivot["id"] = bonn["id"]
pivot.set_index("id").transpose().reset_index().plot(legend=False)
# Out:
# /tmp/ipykernel_8425/1940110633.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot["id"] = bonn["id"]
# <Axes: >
